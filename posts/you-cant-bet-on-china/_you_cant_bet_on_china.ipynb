# %% [markdown]
# # You Can't Bet on China
#
# Scratch notebook for the post `posts/you-cant-bet-on-china/`. Use this to sketch simulations and figures; move stable logic into sibling `.py` files, and let `index.qmd` import from those modules.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# import blogkit  # registers the 'blog' Plotly template
# from blogkit.brand_plotly import HERO, SECONDARY, ACCENT

# %% [markdown]
# ## Scratch
